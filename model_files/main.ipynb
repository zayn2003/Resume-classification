# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV files
file_paths = ["../datasets/01-bols.csv", "../datasets/02-bols.csv", "../datasets/03-bols.csv","../datasets/04-bols.csv","../datasets/05-bols.csv","../datasets/06-bols.csv"]
dataframes = [pd.read_csv(file) for file in file_paths]
data = pd.concat(dataframes, ignore_index=True)

# %%
sns.pairplot(data)
plt.show()
